# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
filename = "FOOD_HN.csv"
data = pd.read_csv(filename)
data.fillna(0)
# Out:
#                                          Name Position Price Quality Service  \
# 0     Ngọc Thạch Handmade - Trà Sữa & Rau Câu      8.3   8.7     8.6     8.4
# 1             Quán Thanh Xuân - Cơm Văn Phòng      8.5   9.0     9.0     8.7
# 2      Bò Tơ Tây Ninh Tài Sanh - KĐT Văn Quán      9.0   7.5     7.5     7.0
# 3                            Tiệm Ăn Đông Lào      7.7   9.3     9.7     9.3
# 4            Bếp Kemkem - Nước Ép & Đồ Ăn Vặt      7.0   7.0     7.0     7.0
# ...                                       ...      ...   ...     ...     ...
# 1975         Gemini Coffee - Nguyễn Chí Thanh      7.5   6.5     6.2     6.3
# 1976             Thủy Đức - Cơm & Đồ Hàn Quốc      7.3   7.3     6.9     7.0
# 1977                       Manzi - Bar & Cafe      7.6   6.8     6.8     7.2
# 1978                  Bánh Xinh - Ẩm Thực Huế      6.3   5.7     7.0     6.0
# 1979              Hàu Nướng & Hải Sản Ông Câu      9.5   9.5     9.5     9.5
#
#      Space ZAvg_Score
# 0      8.0        8.4
# 1      8.0        8.6
# 2      9.0        8.0
# 3      9.3        9.1
# 4      7.0        7.0
# ...    ...        ...
# 1975   7.2        6.7
# 1976   6.5        7.0
# 1977   8.5        7.4
# 1978   6.3        6.3
# 1979   9.5        9.5
#
# [1980 rows x 7 columns]

# %%
data = data.loc[:, data.columns != "Name"]

# %%
data.corr()
# Out:
# Empty DataFrame
# Columns: []
# Index: []
